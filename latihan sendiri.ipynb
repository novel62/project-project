# %%
4+2==6
# Out:
# True

# %%
y=2
x=4
z=y+x
print(z)
# Out:
# 6

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Tidak boleh operator penugasan disebelah kanan:

# %%
2+3=a
# Out:
#   Cell In[6], line 1
#     2+3=a
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a=2+3
a
# Out:
# 5

# %%
num=12
name='sam'
print(f'my number is:{num},my name is:{name}')
# Out:
# my number is:12,my name is:sam

# %%
1==1
# Out:
# True

# %%
d={'key1':2,'key2':4}

# %%
d['key2']
# Out:
# 4

# %%
d={'k1':[1,2,3]}

# %%
list=d['k1']

# %%
list
# Out:
# [1, 2, 3]

# %%
list[0]
# Out:
# 1

# %%
d={'k':{'k3':[1,2]}}

# %%
d['k']
# Out:
# {'k3': [1, 2]}

# %%
d['k']['k3']
# Out:
# [1, 2]

# %%
d['k']['k3'][1]
# Out:
# 2

# %%
tuple=(1,3,5)

# %%
tuple[0]
# Out:
# 1

# %% [markdown]
# ## Tuple tidak boleh dirubah:

# %%
tuple[0]='new'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tuple[0]='new'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# tuple tidak bisa dirubah isinya

# %%
list=[1,3,5]

# %%
list[0]
# Out:
# 1

# %%
list[0]='new'

# %%
list
# Out:
# ['new', 3, 5]

# %%
d=[1,2,3]
d
# Out:
# [1, 2, 3]

# %%
d[0]
# Out:
# 1

# %%
t=lambda a: a*2
t(3)
# Out:
# 6

# %%
def times2(var):return var*2

# %%
times2(4)
# Out:
# 8

# %%
y=lambda var: var*2

# %%
y(2)
# Out:
# 4

# %%
y=[1,2,3,4]

# %%
list(map(times2,y))
# Out:
# [2, 4, 6, 8]

# %%
seq=[1,2,3,4,5]

# %%
map(times2,seq)

# %%
list(map(lambda n:n*5,seq))
# Out:
# [5, 10, 15, 20, 25]

# %%
list(map(lambda n:n%2==0,seq))
# Out:
# [False, True, False, True, False]

# %%
list(filter(lambda n:n%2==0,seq))
# Out:
# [2, 4]

# %%
s='hello my name is novel'

# %%
s.capitalize()
# Out:
# 'Hello my name is novel'

# %%
s.upper()
# Out:
# 'HELLO MY NAME IS NOVEL'

# %%
s.split()
# Out:
# ['hello', 'my', 'name', 'is', 'novel']

# %%
d=[1,2,3,4,5]

# %%
item=d.pop()

# %%
d
# Out:
# [1, 2, 3, 4]

# %%
d.pop()
# Out:
# 4

# %%
d
# Out:
# [1, 2, 3]

# %% [markdown]
# Menghapus list index ke 0

# %%
d.pop(0)
# Out:
# 1

# %%
d
# Out:
# [2, 3]

# %%
d.append(4)

# %%
d
# Out:
# [2, 3, 4]

# %%
5<3
# Out:
# False
